# %% [markdown]
# <a href="https://colab.research.google.com/github/gracemkay/THA4/blob/master/THA4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We (Grace M. Kay and Sadikshya Nepal) tried to do most of our work in Python, but since we were unable to code the very end of it properly, we decided to continue the project on Stata.
#
# We have also uploaded the do file and Stata analysis log for the Stata of our project

# %% [markdown]
# **Research Question **
#
# Our overall hypothesis is that Out Migration in the Chitwan Valley in Nepal will decrease the overall agricultural productivity/output in the region.
#
# In order to test that hypothesis, I am investigating my smaller research question. Does outmigration in Nepal affect the production and cultivation of wheat in the region. As wheat is one of the major crops produced in the country and the region. This research question will help see agricultural output in Chitwan Valley.

# %% [markdown]
# **Data Source **
#
# The Data source for this project comes from the Chitwan Valley [Nepal] Family Study: Labor Outmigration, Agricultural Productivity and Food Security Household Agriculture and Migration Survey.
#
# You can access the data on the google drive [here](https://https://drive.google.com/drive/u/1/folders/14zC51PKe4KMkbua1cRBjRBtB0_ThbpEw)
#
# I have saved a copy of the .dta file on my google drive for access. You will have to download the data as a .dta and upload to Python

# %%
import pandas as pd
df=pd.read_stata('36755-0001-CMS Data.dta')

# %% [markdown]
# **Printed dataframe with all the variables **

# %%
print(df)
# Out:
#         HHID  AGE1 GENDER1  AGE2 GENDER2  AGE3 GENDER3  INTNO  INTDATE  \
# 0     002002    34  Female   NaN     NaN   NaN     NaN     49   720425
# 1     002003    35  Female   NaN     NaN   NaN     NaN     48   720425
# 2     002004    60    Male   NaN     NaN   NaN     NaN     34   720425
# 3     002005    35    Male  35.0  Female   NaN     NaN     34   720421
# 4     002006    65    Male   NaN     NaN   NaN     NaN     22   720420
# 5     002009    60    Male   NaN     NaN   NaN     NaN     20   720420
# 6     002011    40  Female  45.0    Male   NaN     NaN     52   720426
# 7     002012    60    Male   NaN     NaN   NaN     NaN     21   720420
# 8     002013    40  Female   NaN     NaN   NaN     NaN     41   720425
# 9     002016    60    Male   NaN     NaN   NaN     NaN     40   720421
# 10    002017    40    Male   NaN     NaN   NaN     NaN     39   720421
# 11    002020    39  Female   NaN     NaN   NaN     NaN     32   720425
# ...

# %% [markdown]
# **Printed all the Labels to see the variable names.**

# %%
print(list(df))
# Out:
# ['HHID', 'AGE1', 'GENDER1', 'AGE2', 'GENDER2', 'AGE3', 'GENDER3', 'INTNO', 'INTDATE', 'INTRVR', 'INTRW_TYPE', 'CALL', 'PRETOT', 'IWTOT', 'POSTTOT', 'ETHNICITY', 'A_0', 'A1_63', 'A1_64', 'A1_65', 'A1_66', 'A1_67', 'A1_68', 'A1_69', 'A1_70', 'A1_71', 'A1_72', 'A2_63', 'A2_64', 'A2_65', 'A2_66', 'A2_67', 'A2_68', 'A2_69', 'A2_70', 'A2_71', 'A2_72', 'A2A1_63', 'A2A1_64', 'A2A1_65', 'A2A1_66', 'A2A1_67', 'A2A1_68', 'A2A1_69', 'A2A1_70', 'A2A1_71', 'A2A1_72', 'A3_63', 'A3_64', 'A3_65', 'A3_66', 'A3_67', 'A3_68', 'A3_69', 'A3_70', 'A3_71', 'A3_72', 'A4_63', 'A4_64', 'A4_65', 'A4_66', 'A4_67', 'A4_68', 'A4_69', 'A4_70', 'A4_71', 'A4_72', 'A5_63', 'A5_64', 'A5_65', 'A5_66', 'A5_67', 'A5_68', 'A5_69', 'A5_70', 'A5_71', 'A5_72', 'A6_63', 'A6_64', 'A6_65', 'A6_66', 'A6_67', 'A6_68', 'A6_69', 'A6_70', 'A6_71', 'A6_72', 'A7_63', 'A7_64', 'A7_65', 'A7_66', 'A7_67', 'A7_68', 'A7_69', 'A7_70', 'A7_71', 'A7_72', 'A8_63', 'A8_64', 'A8_65', 'A8_66', 'A8_67', 'A8_68', 'A8_69', 'A8_70', 'A8_71', 'A8_72', 
# ...

# %% [markdown]
# **For All Variable that starts with MIG we coded so that the year will change from 63 -> 07, 64-> 08...until 72-16**

# %%
for col in [s for s in df.columns if s.startswith('MIG')]:
    print(col)
    new_col='MIG'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# MIG63
# MIG7
# MIG64
# MIG8
# MIG65
# MIG9
# MIG66
# MIG10
# MIG67
# MIG11
# MIG68
# MIG12
# MIG69
# MIG13
# MIG70
# MIG14
# MIG71
# MIG15
# MIG72
# MIG16

# %% [markdown]
# **Changed dates for the variables in Remmittance REM **

# %%
for col in [s for s in df.columns if s.startswith('REM')]:
    print(col)
    new_col='REM'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# REM63
# REM7
# REM64
# REM8
# REM65
# REM9
# REM66
# REM10
# REM67
# REM11
# REM68
# REM12
# REM69
# REM13
# REM70
# REM14
# REM71
# REM15
# REM72
# REM16

# %% [markdown]
# **Changed Dates for Total Land Owned A2_**

# %%
for col in [s for s in df.columns if s.startswith('A2_')]:
    print(col)
    new_col='A2_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# A2_63
# A2_7
# A2_64
# A2_8
# A2_65
# A2_9
# A2_66
# A2_10
# A2_67
# A2_11
# A2_68
# A2_12
# A2_69
# A2_13
# A2_70
# A2_14
# A2_71
# A2_15
# A2_72
# A2_16

# %% [markdown]
# **Changed Dates for Others Land Used for Cultivation from 63-07 and so on.**

# %%
for col in [s for s in df.columns if s.startswith('A2A1_')]:
    print(col)
    new_col='A2A1_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# A2A1_63
# A2A1_7
# A2A1_64
# A2A1_8
# A2A1_65
# A2A1_9
# A2A1_66
# A2A1_10
# A2A1_67
# A2A1_11
# A2A1_68
# A2A1_12
# A2A1_69
# A2A1_13
# A2A1_70
# A2A1_14
# A2A1_71
# A2A1_15
# A2A1_72
# A2A1_16

# %% [markdown]
# **Rice Planting **

# %%
for col in [s for s in df.columns if s.startswith('B11_')]:
    print(col)
    new_col='B11_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B11_63
# B11_7
# B11_64
# B11_8
# B11_65
# B11_9
# B11_66
# B11_10
# B11_67
# B11_11
# B11_68
# B11_12
# B11_69
# B11_13
# B11_70
# B11_14
# B11_71
# B11_15
# B11_72
# B11_16

# %% [markdown]
# **Rice Planting Land Area Year Change 63- 72**

# %%
for col in [s for s in df.columns if s.startswith('B11A_')]:
    print(col)
    new_col='B11A_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B11A_63
# B11A_7
# B11A_64
# B11A_8
# B11A_65
# B11A_9
# B11A_66
# B11A_10
# B11A_67
# B11A_11
# B11A_68
# B11A_12
# B11A_69
# B11A_13
# B11A_70
# B11A_14
# B11A_71
# B11A_15
# B11A_72
# B11A_16

# %% [markdown]
# **Production of Rice Kgs for each year changed from 63- 72 **

# %%
for col in [s for s in df.columns if s.startswith('B11B_')]:
    print(col)
    new_col='B11B_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B11B_63
# B11B_7
# B11B_64
# B11B_8
# B11B_65
# B11B_9
# B11B_66
# B11B_10
# B11B_67
# B11B_11
# B11B_68
# B11B_12
# B11B_69
# B11B_13
# B11B_70
# B11B_14
# B11B_71
# B11B_15
# B11B_72
# B11B_16

# %% [markdown]
# **Year changed for Sold Rice in Kgs**

# %%
for col in [s for s in df.columns if s.startswith('B11C_')]:
    print(col)
    new_col='B11C_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B11C_63
# B11C_7
# B11C_64
# B11C_8
# B11C_65
# B11C_9
# B11C_66
# B11C_10
# B11C_67
# B11C_11
# B11C_68
# B11C_12
# B11C_69
# B11C_13
# B11C_70
# B11C_14
# B11C_71
# B11C_15
# B11C_72
# B11C_16

# %% [markdown]
# **Year changed for Wheat Planting **

# %%
for col in [s for s in df.columns if s.startswith('B13_')]:
    print(col)
    new_col='B13_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B13_63
# B13_7
# B13_64
# B13_8
# B13_65
# B13_9
# B13_66
# B13_10
# B13_67
# B13_11
# B13_68
# B13_12
# B13_69
# B13_13
# B13_70
# B13_14
# B13_71
# B13_15
# B13_72
# B13_16

# %% [markdown]
# **Year changed for Wheat Planting Area **

# %%
for col in [s for s in df.columns if s.startswith('B13A_')]:
    print(col)
    new_col='B13A_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B13A_63
# B13A_7
# B13A_64
# B13A_8
# B13A_65
# B13A_9
# B13A_66
# B13A_10
# B13A_67
# B13A_11
# B13A_68
# B13A_12
# B13A_69
# B13A_13
# B13A_70
# B13A_14
# B13A_71
# B13A_15
# B13A_72
# B13A_16

# %% [markdown]
# **Year Changed for Production of Wheat **

# %%
for col in [s for s in df.columns if s.startswith('B13B_')]:
    print(col)
    new_col='B13B_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B13B_63
# B13B_7
# B13B_64
# B13B_8
# B13B_65
# B13B_9
# B13B_66
# B13B_10
# B13B_67
# B13B_11
# B13B_68
# B13B_12
# B13B_69
# B13B_13
# B13B_70
# B13B_14
# B13B_71
# B13B_15
# B13B_72
# B13B_16

# %% [markdown]
# **Year changed for sold wheat **

# %%
for col in [s for s in df.columns if s.startswith('B13C_')]:
    print(col)
    new_col='B13C_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B13C_63
# B13C_7
# B13C_64
# B13C_8
# B13C_65
# B13C_9
# B13C_66
# B13C_10
# B13C_67
# B13C_11
# B13C_68
# B13C_12
# B13C_69
# B13C_13
# B13C_70
# B13C_14
# B13C_71
# B13C_15
# B13C_72
# B13C_16

# %% [markdown]
# **Buckwheat planting year changed **

# %%
for col in [s for s in df.columns if s.startswith('B17_1_')]:
    print(col)
    new_col='B17_1_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B17_1_63
# B17_1_7
# B17_1_64
# B17_1_8
# B17_1_65
# B17_1_9
# B17_1_66
# B17_1_10
# B17_1_67
# B17_1_11
# B17_1_68
# B17_1_12
# B17_1_69
# B17_1_13
# B17_1_70
# B17_1_14
# B17_1_71
# B17_1_15
# B17_1_72
# B17_1_16

# %% [markdown]
# **Year for Buckwheat Planting changed from Nepali Calendar to A.D. calendar **

# %%
for col in [s for s in df.columns if s.startswith('B17_1A_')]:
    print(col)
    new_col='B17_1A_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B17_1A_63
# B17_1A_7
# B17_1A_64
# B17_1A_8
# B17_1A_65
# B17_1A_9
# B17_1A_66
# B17_1A_10
# B17_1A_67
# B17_1A_11
# B17_1A_68
# B17_1A_12
# B17_1A_69
# B17_1A_13
# B17_1A_70
# B17_1A_14
# B17_1A_71
# B17_1A_15
# B17_1A_72
# B17_1A_16

# %%
for col in [s for s in df.columns if s.startswith('B17_1B_')]:
    print(col)
    new_col='B17_1B_'+str(int(col[-2:])-56)
    print(new_col)
    df.rename(columns={col:new_col}, inplace=True)
    pass
# Out:
# B17_1B_63
# B17_1B_7
# B17_1B_64
# B17_1B_8
# B17_1B_65
# B17_1B_9
# B17_1B_66
# B17_1B_10
# B17_1B_67
# B17_1B_11
# B17_1B_68
# B17_1B_12
# B17_1B_69
# B17_1B_13
# B17_1B_70
# B17_1B_14
# B17_1B_71
# B17_1B_15
# B17_1B_72
# B17_1B_16

# %% [markdown]
# **We wanted to see the sum of all the values from household to community level, so we summed the vaues in every column that was applicable. **

# %%
import numpy as np
df_sum(df, 'sum', )
df_sum = df.sum(axis = 1, skipna=True, level=None)
print(list(df_sum))
# Out:
# [3861626.1000037193, 1205901.5, 1224834.0, 1756454.3000001907, 886846.0, 778718.5, 788268.0, 740633.5, 750801.0, 3728052.5, 722883.0, 723120.0, 737438.0, 732442.0, 732129.0, 722767.0, 725381.5, 1032703.0, 991082.0, 722364.0, 722691.0, 789955.150000006, 724986.0, 733027.5, 1102445.0, 723227.0, 724675.0, 831150.0, 724158.0, 2233610.0, 1045297.0, 4625415.5, 923225.8999999166, 738907.0, 723797.0, 724409.0, 723702.0, 722654.0, 774409.0, 722603.0, 1205767.0, 722474.0, 722841.0, 938359.0, 722555.0, 722042.0, 5186962.0, 1904368.0, 724792.0, 722434.0, 722258.0, 722492.0, 723591.0, 722323.0, 722303.0, 722252.0, 755287.0, 722275.0, 722094.0, 1670653.0, 7205991.5, 2525759.850001812, 1748195.0, 888900.0, 728942.0, 1506769.0, 1103511.0, 888246.0, 2482954.0, 1366318.0, 2562251.0, 859534.0, 2821037.0, 1909549.0, 1491099.5, 1002695.0, 2023635.5, 842742.0, 4208083.0, 751772.0, 724078.0, 916032.5, 1232409.0, 2863451.5, 1649220.0, 2397803.5, 955419.0, 1899183.5, 1515877.0, 820276.0, 3302068.0, 1305900.0
# ...

# %%
df
# Out:
#         HHID  AGE1 GENDER1  AGE2 GENDER2  AGE3 GENDER3  INTNO  INTDATE  \
# 0     002002    34  Female   NaN     NaN   NaN     NaN     49   720425
# 1     002003    35  Female   NaN     NaN   NaN     NaN     48   720425
# 2     002004    60    Male   NaN     NaN   NaN     NaN     34   720425
# 3     002005    35    Male  35.0  Female   NaN     NaN     34   720421
# 4     002006    65    Male   NaN     NaN   NaN     NaN     22   720420
# 5     002009    60    Male   NaN     NaN   NaN     NaN     20   720420
# 6     002011    40  Female  45.0    Male   NaN     NaN     52   720426
# 7     002012    60    Male   NaN     NaN   NaN     NaN     21   720420
# 8     002013    40  Female   NaN     NaN   NaN     NaN     41   720425
# 9     002016    60    Male   NaN     NaN   NaN     NaN     40   720421
# 10    002017    40    Male   NaN     NaN   NaN     NaN     39   720421
# 11    002020    39  Female   NaN     NaN   NaN     NaN     32   720425
# ...

# %% [markdown]
# **While Summing we asked that all the values that says household does not exist get dropped. **

# %% [markdown]
# **Exported the dataframe to Excel **

# %%
dfn = df.sum(axis=0, skipna=True)
dfn.to_excel("test.xlsx")

# %%
dfnt = dfn.transpose()
dfnt.to_excel("test_t.xlsx")

# %% [markdown]
# **This was for values that could not be summed, but was a count of yes or no. So we coded the count for each variable where a yes or no question was asked.**

# %%
new = pd.DataFrame()
for j in [11,13]:
  for i in range(7, 17):
    get = df["B"+str(j)+"_"+str(i)].value_counts() 
    print(get)
    #get.append(pd.Series("colname"+"B"+str(j)+"_"+str(i)))
    new = pd.concat([new, get])
    
new = pd.concat([dfn, new])
new.to_excel("test_stck1.xlsx")
# Out:
# Yes                         1142
# Household does not exist     841
# No                           272
# Name: B11_7, dtype: int64
# Yes                                        1153
# Household does not exist                    742
# No                                          263
# Planting by other in rent                    59
# Planting by self and some part by other      37
# Name: B11_8, dtype: int64
# Yes                                        1188
# Household does not exist                    662
# No                                          299
# Planting by other in rent                    65
# Planting by self and some part by other      40
# Name: B11_9, dtype: int64
# Yes                                        1237
# Household does not exist                    565
# No                                          338
# Planting by other in rent                    72
# Planting by self and some part by other      42
# Name: B11_10, dtype: int64
# ...

# %% [markdown]
# **However, after doing all this I was not able to figure out how to export this dataframe into excel so we moved this project to Stata. Please check the google doc attached in this folder for further how we used Stata to complete this research question. **
